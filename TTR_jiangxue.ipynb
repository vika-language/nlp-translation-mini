# %%
import re

# 许渊冲译文
xu = "From hill to hill no bird in flight; From path to path no man in sight. A lonely fisherman afloat, Is fishing snow in lonely boat."

# 斯奈德译文
snyder = "These thousand peaks cut off the flight of birds, On all the trails, human tracks are gone. A single boat — coat — hat — an old man! Alone fishing chill river snow."

def ttr(text):
    # 提取单词（按字母，忽略标点）
    words = re.findall(r'\b\w+\b', text.lower())
    if not words:
        return 0
    unique_words = len(set(words))
    total_words = len(words)
    return round(unique_words / total_words, 3)

print(f"许渊冲译文 TTR: {ttr(xu)}")
print(f"斯奈德译文 TTR: {ttr(snyder)}")
# Out:
# 许渊冲译文 TTR: 0.692
# 斯奈德译文 TTR: 0.967

# %%
import matplotlib.pyplot as plt
import numpy as np

# 维度名称
categories = ['形式对仗', '语义意象', '音韵节奏', '表情功能']
# 评分数据（1-5分）
xu_scores = [5, 5, 5, 5]
snyder_scores = [2, 2, 1, 2]

# 雷达图绘制
angles = np.linspace(0, 2 * np.pi, len(categories), endpoint=False).tolist()
xu_scores += xu_scores[:1]
snyder_scores += snyder_scores[:1]
angles += angles[:1]

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.plot(angles, xu_scores, 'o-', linewidth=2, label='许渊冲')
ax.fill(angles, xu_scores, alpha=0.25)
ax.plot(angles, snyder_scores, 'o-', linewidth=2, label='斯奈德')
ax.fill(angles, snyder_scores, alpha=0.25)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories)
ax.set_ylim(0, 5)
ax.legend(loc='upper right')
ax.set_title('《江雪》两译本对比 (基于课堂评析)', size=14)
plt.show()

# %% [markdown]
# # 分析结论
# '''
# 根据课堂评析，将《江雪》两个英译本在四个维度上的表现转化为1-5分评分：
# - **形式对仗**: 许渊冲（5）> 斯奈德（2），许译句式工整，复刻原文对仗结构。
# - **语义意象**: 许渊冲（5）> 斯奈德（2），"fishing snow"传神，斯奈德过于实描。
# - **音韵节奏**: 许渊冲（5）> 斯奈德（1），许译押韵，自由诗体缺乏音乐性。
# - **表情功能**: 许渊冲（5）> 斯奈德（2），重复"lonely"强化孤傲情感。
#
# 雷达图直观展示了许渊冲译本在多维度上的优势，与课堂评析结论一致。
# '''
